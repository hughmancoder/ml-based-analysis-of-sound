# %% [markdown]
# # Test Chinese (Mel+CQT)

# %%
import sys
import torch
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm import tqdm

ROOT = Path.cwd()
while ROOT != ROOT.parent and not (ROOT / "src").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.models.CNN import CNN
from src.test.utils import  display_formatted_results, find_best_threshold
from src.test.utils_mel_cqt import run_inference

MODEL_WEIGHTS     = ROOT / "src/models/saved_weights/Chinese_mel_cqt_v1/best_val.pt"
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Run on A Touch of Zen Dataset (Mel+CQT)

# %%
test_manifest_csv = ROOT / "data/test/a-touch-of-zen.csv"

preds_arr, gts_arr, sample_ids, audio_cfg, valid_labels, label_to_idx = run_inference(
    model_cls=CNN,
    model_kwargs={"in_ch": 4},
    model_weights_path=MODEL_WEIGHTS,
    device=DEVICE,
    test_manifest_csv=test_manifest_csv,
    root=ROOT,
)
# Out:
# Running inference on 85 samples against 15 classes...
# 100%|██████████| 85/85 [01:13<00:00,  1.16it/s]

# %% [markdown]
# ## Tune classification threshold probability
#
# Optimising macro F1 means:
# - You care equally about rare and common instruments
#
# Optimising micro F1 means:
# - You care about overall instrument detection performance
# - Every correctly detected instrument occurrence matters equally
# - Common instruments dominate

# %%
from src.test.utils import find_best_threshold
best_t = find_best_threshold(preds_arr, gts_arr, valid_labels)
print(f"Best threshold found: {best_t:.2f}")
# print(valid_labels)
# Out:
# Threshold  | Micro F1   | Macro F1   | Subset Acc
# --------------------------------------------------
# 0.05       | 0.2812     | 0.1517     | 0.00%
# 0.10       | 0.2748     | 0.1488     | 0.00%
# 0.15       | 0.2541     | 0.1331     | 1.18%
# 0.20       | 0.2479     | 0.1258     | 1.18%
# 0.25       | 0.2423     | 0.1199     | 1.18%
# 0.30       | 0.2262     | 0.1068     | 1.18%
# 0.35       | 0.2243     | 0.1070     | 1.18%
# 0.40       | 0.2217     | 0.1041     | 1.18%
# 0.45       | 0.2201     | 0.1030     | 1.18%
# 0.50       | 0.2165     | 0.0991     | 1.18%
# 0.55       | 0.2100     | 0.0971     | 1.18%
# 0.60       | 0.2110     | 0.0971     | 1.18%
# 0.65       | 0.1863     | 0.0796     | 1.18%
# 0.70       | 0.1750     | 0.0761     | 1.18%
# 0.75       | 0.1667     | 0.0604     | 1.18%
# 0.80       | 0.1590     | 0.0580     | 0.00%
# 0.85       | 0.1530     | 0.0560     | 0.00%
# 0.90       | 0.1344     | 0.0480     | 0.00%
# 0.95       | 0.1229     | 0.0419     | 0.00%
#
# Best Threshold (Micro F1): 0.05 (Score: 0.2812)
# Best Threshold (Macro F1): 0.05 (Score: 0.1517)
# Best threshold found: 0.05

# %%
import numpy as np
from sklearn.metrics import classification_report, accuracy_score, hamming_loss


def evaluate_multilabel_performance(
    all_preds,
    all_gt,
    class_list,
    sample_ids=None,
    threshold=0.5,
    debug=False,
    zero_division=0,
):
    classes = [c.strip().lower() for c in class_list]
    probs = np.asarray(all_preds)
    gts = np.asarray(all_gt).astype(int)

    if probs.shape != gts.shape:
        raise ValueError(f"Shape mismatch: preds {probs.shape} vs gts {gts.shape}")

    preds = (probs >= threshold).astype(int)

    num_samples, num_classes = preds.shape

    # ---- Key counts ----
    total_pos_gt = int(gts.sum())
    total_pos_pred = int(preds.sum())
    total_entries = int(num_samples * num_classes)

    # Confusion totals across ALL labels (micro)
    tp = int(((preds == 1) & (gts == 1)).sum())
    fp = int(((preds == 1) & (gts == 0)).sum())
    fn = int(((preds == 0) & (gts == 1)).sum())
    tn = int(((preds == 0) & (gts == 0)).sum())

    # ---- None prediction rate ----
    none_pred_mask = preds.sum(axis=1) == 0
    num_none = int(none_pred_mask.sum())

    # ---- Metrics ----
    subset_acc = accuracy_score(gts, preds)                      # exact match
    hamming_acc = 1.0 - hamming_loss(gts, preds)                 # label-wise accuracy

    report = classification_report(
        gts,
        preds,
        target_names=classes,
        output_dict=True,
        zero_division=zero_division,
    )

    # ---- Print summary ----
    print(f"Classification threshold probability: {threshold}")
    print(f"Samples: {num_samples} | Classes: {num_classes} | Decisions: {total_entries}")
    print(f"GT positives: {total_pos_gt} ({total_pos_gt/total_entries:.2%} of all decisions)")
    print(f"Pred positives: {total_pos_pred} ({total_pos_pred/total_entries:.2%} of all decisions)")
    print(f"Predicted 'None' (all-zero): {num_none} ({num_none/num_samples:.2%})")
    print("")
    print(f"Hamming accuracy (label-wise): {hamming_acc:.2%}")
    print(f"Subset accuracy (exact match): {subset_acc:.2%}")
    print(f"Micro F1:  {report['micro avg']['f1-score']:.4f}")
    print(f"Macro F1:  {report['macro avg']['f1-score']:.4f}")
    # print(f"Micro Prec:{report['micro avg']['precision']:.4f} | Micro Rec:{report['micro avg']['recall']:.4f}")
    print("")

    print(f"TP={tp} FP={fp} FN={fn} TN={tn}")
    if total_pos_pred < max(5, 0.02 * total_pos_gt):
        print("WARNING: Very few positive predictions relative to GT positives.")
        print("         Your threshold is likely too high, or logits are miscalibrated.\n")

    # ---- Per-class table ----
    pos_per_class = gts.sum(axis=0)
    print(f"{'Instrument':<15} | {'Prec':>6} | {'Recall':>6} | {'F1':>6} | {'Support':>7} | {'Pred':>5}")
    print("-" * 70)

    for i, name in enumerate(classes):
        support = int(pos_per_class[i])
        pred_count = int(preds[:, i].sum())

        if support == 0:
            print(f"{name:<15} | {'  n/a':>6} | {'  n/a':>6} | {'  n/a':>6} | {support:>7} | {pred_count:>5}")
            continue

        prec = report[name]["precision"]
        rec = report[name]["recall"]
        f1 = report[name]["f1-score"]
        print(f"{name:<15} | {prec:6.2f} | {rec:6.2f} | {f1:6.2f} | {support:>7} | {pred_count:>5}")

    # ---- Debug examples where GT had positives ----
    if debug and sample_ids is not None:
        print("\n--- DEBUG: Examples where GT has at least one label ---")
        gt_nonzero = np.where(gts.sum(axis=1) > 0)[0]
        for idx in gt_nonzero[:]:
            pred_names = [classes[j] for j, v in enumerate(preds[idx]) if v]
            gt_names = [classes[j] for j, v in enumerate(gts[idx]) if v]
            print(f"ID: {sample_ids[idx]}")
            print(f"  Predicted: {pred_names if pred_names else '(none)'}")
            print(f"  Actual:    {gt_names if gt_names else '(none)'}")
            print("-" * 30)

    return report

# Default is 0.5; could optionally adjust based on precision-recall tradeoff desired
# threshold_probability = 0.5

threshold_probability = best_t
# threshold_probability = 0.9

results = evaluate_multilabel_performance(
    all_preds=preds_arr, 
    all_gt=gts_arr, 
    class_list=valid_labels, 
    sample_ids=sample_ids,
    threshold=threshold_probability,
    debug=True
)
# Out:
# Classification threshold probability: 0.05
# Samples: 85 | Classes: 15 | Decisions: 1275
# GT positives: 284 (22.27% of all decisions)
# Pred positives: 356 (27.92% of all decisions)
# Predicted 'None' (all-zero): 0 (0.00%)
#
# Hamming accuracy (label-wise): 63.92%
# Subset accuracy (exact match): 0.00%
# Micro F1:  0.2812
# Macro F1:  0.1517
#
# TP=90 FP=266 FN=194 TN=725
# Instrument      |   Prec | Recall |     F1 | Support |  Pred
# ----------------------------------------------------------------------
# strings         |   0.00 |   0.00 |   0.00 |      46 |     0
# brass           |   0.39 |   0.91 |   0.54 |      32 |    75
# percussion      |   0.33 |   0.83 |   0.47 |      29 |    73
# woodwind        |   0.00 |   0.00 |   0.00 |      30 |     0
# sheng           |   0.36 |   0.77 |   0.49 |      30 |    64
# dizi            |   0.14 |   0.17 |   0.15 |      12 |    14
# timpani         |   0.00 |   0.00 |   0.00 |      26 |     0
# erhu            |   0.27 |   0.30 |   0.29 |      23 |    26
# pipa            |   0.33 |   0.03 |   0.06 |      29 |     3
# suona           |   0.00 |   0.00 |   0.00 |       4 |     1
# guzheng         |   0.03 |   1.00 |   0.05 |       2 |    79
# piano           |   0.00 |   0.00 |   0.00 |       2 |     0
# guqin           |   0.00 |   0.00 |   0.00 |      10 |    11
# xiao            |   0.20 |   0.25 |   0.22 |       8 |    10
# yangqin         |   0.00 |   0.00 |   0.00 |       1 |     0
#
# --- DEBUG: Examples where GT has at least one label ---
# ID: 0.41.14—00.42.06
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'brass', 'woodwind', 'timpani']
# ------------------------------
# ID: 00.00.00—00.02.14
#   Predicted: ['brass', 'sheng', 'erhu', 'guzheng']
#   Actual:    ['strings', 'brass', 'percussion', 'woodwind', 'erhu', 'suona', 'guzheng']
# ------------------------------
# ID: 00.02.15—00.03.52
#   Predicted: ['brass', 'percussion', 'sheng', 'dizi', 'erhu', 'suona', 'guzheng', 'guqin']
#   Actual:    ['brass', 'percussion', 'woodwind', 'sheng', 'dizi', 'erhu', 'pipa']
# ------------------------------
# ID: 00.03.52—00.04.07
#   Predicted: ['brass', 'sheng', 'dizi', 'erhu']
#   Actual:    ['brass', 'percussion']
# ------------------------------
# ID: 00.04.07—00.05.10
#   Predicted: ['brass', 'dizi', 'xiao']
#   Actual:    ['strings', 'brass', 'percussion', 'guqin', 'xiao']
# ------------------------------
# ID: 00.05.22—00.06.40
#   Predicted: ['brass', 'percussion', 'dizi', 'guzheng']
#   Actual:    ['sheng', 'erhu', 'pipa', 'yangqin']
# ------------------------------
# ID: 00.07.09—00.07.11
#   Predicted: ['brass', 'percussion', 'dizi', 'erhu', 'guzheng', 'guqin', 'xiao']
#   Actual:    ['sheng']
# ------------------------------
# ID: 00.08.35—00.08.48
#   Predicted: ['brass', 'percussion', 'sheng', 'erhu', 'guzheng']
#   Actual:    ['brass', 'percussion']
# ------------------------------
# ID: 00.10.22—00.11.55
#   Predicted: ['brass', 'percussion', 'sheng', 'erhu', 'guzheng']
#   Actual:    ['sheng', 'erhu', 'pipa']
# ------------------------------
# ID: 00.12.00—00.12.16
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['guqin', 'xiao']
# ------------------------------
# ID: 00.12.33—00.13.02
#   Predicted: ['brass', 'percussion', 'erhu', 'guzheng', 'xiao']
#   Actual:    ['dizi', 'pipa']
# ------------------------------
# ID: 00.17.07—00.21.44
#   Predicted: ['brass', 'percussion', 'dizi', 'erhu', 'guzheng']
#   Actual:    ['brass', 'sheng', 'piano']
# ------------------------------
# ID: 00.21.48—00.22.13
#   Predicted: ['brass', 'percussion', 'dizi', 'erhu', 'pipa', 'guzheng', 'guqin', 'xiao']
#   Actual:    ['strings', 'brass', 'percussion', 'sheng']
# ------------------------------
# ID: 00.22.38—00.23.26
#   Predicted: ['brass', 'percussion', 'sheng', 'dizi', 'guzheng']
#   Actual:    ['pipa']
# ------------------------------
# ID: 00.25.35—00.25.46
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['brass', 'timpani']
# ------------------------------
# ID: 00.25.46—00.26.00
#   Predicted: ['brass', 'sheng', 'erhu', 'guzheng']
#   Actual:    ['strings', 'percussion', 'woodwind', 'sheng', 'timpani', 'erhu', 'pipa']
# ------------------------------
# ID: 00.27.54—00.28.26
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['guqin']
# ------------------------------
# ID: 00.30.18—00.33.40
#   Predicted: ['sheng', 'guzheng']
#   Actual:    ['strings', 'brass', 'woodwind', 'sheng', 'piano']
# ------------------------------
# ID: 00.34.51—00.34.55
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['brass', 'woodwind', 'timpani']
# ------------------------------
# ID: 00.37.41—00.38.57
#   Predicted: ['brass', 'percussion', 'sheng']
#   Actual:    ['brass', 'timpani', 'pipa']
# ------------------------------
# ID: 00.39.42—00.40.25
#   Predicted: ['brass', 'percussion', 'guzheng', 'guqin']
#   Actual:    ['pipa']
# ------------------------------
# ID: 00.43.06—00.44.02
#   Predicted: ['percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'brass', 'woodwind', 'sheng', 'pipa']
# ------------------------------
# ID: 00.44.40—00.47.03
#   Predicted: ['percussion', 'sheng', 'guzheng']
#   Actual:    ['woodwind', 'sheng', 'erhu', 'guqin', 'xiao']
# ------------------------------
# ID: 00.47.04—00.47.30
#   Predicted: ['brass', 'dizi', 'erhu', 'guzheng']
#   Actual:    ['woodwind', 'sheng', 'erhu', 'pipa']
# ------------------------------
# ID: 00.47.49—00.50.00
#   Predicted: ['brass', 'sheng', 'guzheng']
#   Actual:    ['strings', 'woodwind', 'timpani', 'erhu', 'pipa']
# ------------------------------
# ID: 00.50.10—00.53.06
#   Predicted: ['percussion', 'sheng', 'pipa', 'guzheng']
#   Actual:    ['guqin']
# ------------------------------
# ID: 00.53.07—00.54.18
#   Predicted: ['brass', 'sheng', 'erhu', 'guzheng']
#   Actual:    ['strings', 'woodwind', 'sheng', 'dizi', 'erhu', 'guzheng']
# ------------------------------
# ID: 00.54.19—00.55.18
#   Predicted: ['brass', 'sheng', 'erhu']
#   Actual:    ['strings', 'woodwind', 'sheng', 'timpani', 'erhu', 'guqin', 'xiao']
# ------------------------------
# ID: 00.55.38—00.56.10
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'woodwind', 'sheng']
# ------------------------------
# ID: 00.57.32—00.59.02
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'sheng', 'timpani', 'pipa']
# ------------------------------
# ID: 00.59.30—00.59.52
#   Predicted: ['percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'percussion']
# ------------------------------
# ID: 1.00.23—1.00.38
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['woodwind', 'erhu', 'pipa']
# ------------------------------
# ID: 1.01.30—1.02.28
#   Predicted: ['brass', 'percussion', 'guzheng']
#   Actual:    ['percussion', 'pipa']
# ------------------------------
# ID: 1.04.14—1.05.47
#   Predicted: ['percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'percussion', 'sheng', 'timpani', 'pipa']
# ------------------------------
# ID: 1.06.18—1.08.26
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'woodwind', 'sheng', 'timpani', 'pipa']
# ------------------------------
# ID: 1.09.22—1.09.33
#   Predicted: ['percussion', 'sheng', 'guzheng', 'guqin']
#   Actual:    ['percussion']
# ------------------------------
# ID: 1.11.15—1.11.48
#   Predicted: ['brass', 'percussion', 'guzheng']
#   Actual:    ['strings', 'percussion']
# ------------------------------
# ID: 1.16.58—1.17.43
#   Predicted: ['percussion', 'sheng', 'guzheng']
#   Actual:    ['percussion', 'suona']
# ------------------------------
# ID: 1.18.12—1.19.00
#   Predicted: ['brass', 'percussion']
#   Actual:    ['brass', 'percussion', 'erhu', 'suona']
# ------------------------------
# ID: 1.20.00—1.20.20
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'sheng', 'pipa']
# ------------------------------
# ID: 1.21.10—1.23.20
#   Predicted: ['percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'brass', 'percussion', 'woodwind', 'dizi', 'erhu', 'pipa']
# ------------------------------
# ID: 1.23.44—1.27.15
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['percussion', 'timpani']
# ------------------------------
# ID: 1.24.25—1.24.40
#   Predicted: ['brass', 'percussion', 'sheng', 'erhu', 'guzheng']
#   Actual:    ['strings', 'timpani', 'pipa']
# ------------------------------
# ID: 1.25.25—1.27.04
#   Predicted: ['brass', 'percussion', 'sheng', 'erhu', 'guzheng', 'xiao']
#   Actual:    ['guqin', 'xiao']
# ------------------------------
# ID: 1.33.25—1.33.40
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng', 'guqin']
#   Actual:    ['sheng', 'erhu', 'pipa']
# ------------------------------
# ID: 1.34.08—1.35.40
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['xiao']
# ------------------------------
# ID: 1.36.03—1.37.38
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['brass', 'woodwind', 'sheng', 'timpani']
# ------------------------------
# ID: 1.39.31—1.40.24
#   Predicted: ['brass', 'percussion', 'sheng', 'erhu', 'guzheng']
#   Actual:    ['strings', 'brass', 'percussion']
# ------------------------------
# ID: 1.43.38—1.45.00
#   Predicted: ['brass', 'percussion', 'sheng', 'dizi', 'guzheng']
#   Actual:    ['strings', 'brass', 'woodwind', 'dizi', 'timpani', 'guqin', 'xiao']
# ------------------------------
# ID: 1.45.36—1.46.50
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'woodwind', 'erhu', 'pipa']
# ------------------------------
# ID: 1.46.50—1.47.08
#   Predicted: ['brass', 'percussion', 'sheng', 'erhu', 'guzheng']
#   Actual:    ['suona']
# ------------------------------
# ID: 1.48.00—1.48.45
#   Predicted: ['brass', 'percussion', 'sheng', 'dizi', 'guzheng']
#   Actual:    ['strings', 'brass', 'percussion']
# ------------------------------
# ID: 1.49.49—1.50.24
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['brass', 'percussion', 'woodwind', 'sheng', 'dizi', 'erhu', 'pipa']
# ------------------------------
# ID: 1.50.25—1.50.45
#   Predicted: ['brass', 'sheng', 'erhu', 'guzheng']
#   Actual:    ['guqin', 'xiao']
# ------------------------------
# ID: 1.53.35—1.53.59
#   Predicted: ['brass', 'percussion', 'sheng', 'erhu', 'guzheng']
#   Actual:    ['strings', 'brass', 'percussion']
# ------------------------------
# ID: 1.55.14—1.55.31
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'percussion']
# ------------------------------
# ID: 1.56.01—1.56.24
#   Predicted: ['brass', 'percussion', 'pipa', 'guzheng', 'xiao']
#   Actual:    ['strings', 'woodwind', 'erhu', 'pipa']
# ------------------------------
# ID: 1.57.33—1.57.40
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'brass']
# ------------------------------
# ID: 1.59.17—2.00.35
#   Predicted: ['brass', 'percussion', 'sheng', 'erhu', 'guzheng']
#   Actual:    ['strings', 'sheng', 'timpani']
# ------------------------------
# ID: 2.01.03—2.02.07
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'brass', 'sheng', 'timpani']
# ------------------------------
# ID: 2.03.33—2.04.49
#   Predicted: ['brass', 'percussion', 'sheng', 'dizi', 'erhu', 'guzheng', 'guqin']
#   Actual:    ['strings', 'brass', 'timpani']
# ------------------------------
# ID: 2.05.45—2.05.46
#   Predicted: ['brass', 'percussion', 'sheng', 'dizi', 'xiao']
#   Actual:    ['sheng']
# ------------------------------
# ID: 2.07.28—2.08.05
#   Predicted: ['percussion', 'sheng', 'erhu', 'guzheng']
#   Actual:    ['strings', 'percussion']
# ------------------------------
# ID: 2.11.07—2.13.40
#   Predicted: ['brass', 'percussion', 'guzheng']
#   Actual:    ['strings', 'brass', 'sheng', 'timpani', 'pipa']
# ------------------------------
# ID: 2.14.18—2.14.38
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'timpani']
# ------------------------------
# ID: 2.14.40—2.15.17
#   Predicted: ['brass', 'percussion', 'guzheng']
#   Actual:    ['percussion', 'woodwind', 'erhu', 'pipa']
# ------------------------------
# ID: 2.17.33—2.19.10
#   Predicted: ['brass', 'percussion', 'guzheng']
#   Actual:    ['strings', 'timpani', 'erhu', 'pipa']
# ------------------------------
# ID: 2.19.10—2.20.16
#   Predicted: ['brass', 'percussion', 'dizi', 'erhu', 'guzheng', 'guqin']
#   Actual:    ['strings', 'timpani']
# ------------------------------
# ID: 2.20.45—2.26.18
#   Predicted: ['brass', 'percussion', 'guzheng', 'xiao']
#   Actual:    ['strings', 'percussion', 'woodwind', 'dizi', 'erhu', 'pipa']
# ------------------------------
# ID: 2.26.16—2.26.18
#   Predicted: ['brass', 'percussion', 'guzheng', 'guqin', 'xiao']
#   Actual:    ['strings', 'brass', 'woodwind', 'sheng', 'dizi', 'erhu']
# ------------------------------
# ID: 2.26.18—2.26.34
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['dizi', 'erhu', 'pipa', 'guqin']
# ------------------------------
# ID: 2.26.35—2.26.58
#   Predicted: ['brass', 'sheng', 'guzheng']
#   Actual:    ['strings']
# ------------------------------
# ID: 2.28.04—2.30.04
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'percussion', 'woodwind', 'sheng', 'timpani', 'erhu', 'pipa']
# ------------------------------
# ID: 2.31.36—2.32.30
#   Predicted: ['brass', 'percussion', 'guzheng']
#   Actual:    ['strings', 'timpani']
# ------------------------------
# ID: 2.36.43—2.38.02
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng', 'guqin']
#   Actual:    ['strings', 'brass', 'percussion', 'woodwind', 'sheng', 'dizi']
# ------------------------------
# ID: 2.39.34—2.41.28
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng', 'guqin']
#   Actual:    ['strings', 'timpani']
# ------------------------------
# ID: 2.43.48—2.44.40
#   Predicted: ['brass', 'percussion', 'sheng', 'erhu', 'guzheng']
#   Actual:    ['strings', 'brass', 'woodwind', 'sheng', 'dizi', 'timpani']
# ------------------------------
# ID: 2.46.23—2.49.27
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'brass', 'percussion', 'sheng']
# ------------------------------
# ID: 2.51.49—2.51.53
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['brass', 'percussion']
# ------------------------------
# ID: 2.52.15—2.54.28
#   Predicted: ['brass', 'percussion', 'sheng', 'guzheng']
#   Actual:    ['strings', 'brass', 'woodwind', 'timpani']
# ------------------------------
# ID: 2.54.29—2.56.00
#   Predicted: ['brass', 'sheng', 'erhu', 'guzheng']
#   Actual:    ['brass', 'percussion', 'woodwind']
# ------------------------------
# ID: 2.57.21—2.58.36
#   Predicted: ['brass', 'percussion', 'guzheng', 'xiao']
#   Actual:    ['strings', 'woodwind', 'dizi']
# ------------------------------

# %% [markdown]
# ### Classification Report

# %%
display_formatted_results(results)
# Out:
# --- Detailed Classification Report ---
# <style type="text/css">
# #T_6f642_row0_col2, #T_6f642_row3_col2, #T_6f642_row6_col2, #T_6f642_row9_col2, #T_6f642_row11_col2, #T_6f642_row12_col2, #T_6f642_row14_col2 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_6f642_row1_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_6f642_row2_col2 {
#   background-color: #253595;
#   color: #f1f1f1;
# }
# #T_6f642_row4_col2 {
#   background-color: #1e2e85;
#   color: #f1f1f1;
# }
# #T_6f642_row5_col2 {
#   background-color: #b4e2b6;
#   color: #000000;
# }
# #T_6f642_row7_col2 {
#   background-color: #3aaec3;
#   color: #f1f1f1;
# }
# #T_6f642_row8_col2 {
#   background-color: #eff9b5;
#   color: #000000;
# }
# #T_6f642_row10_col2 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_6f642_row13_col2 {
#   background-color: #6fc7bd;
#   color: #000000;
# }
# #T_6f642_row15_col2 {
#   background-color: #3cb1c3;
#   color: #f1f1f1;
# }
# #T_6f642_row16_col2 {
#   background-color: #b7e3b6;
#   color: #000000;
# }
# #T_6f642_row17_col2 {
#   background-color: #7ecdbb;
#   color: #000000;
# }
# #T_6f642_row18_col2 {
#   background-color: #4cbac2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6f642">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f642_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_6f642_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_6f642_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_6f642_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f642_level0_row0" class="row_heading level0 row0" >strings</th>
#       <td id="T_6f642_row0_col0" class="data row0 col0" >0.0000</td>
#       <td id="T_6f642_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_6f642_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_6f642_row0_col3" class="data row0 col3" >46</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row1" class="row_heading level0 row1" >brass</th>
#       <td id="T_6f642_row1_col0" class="data row1 col0" >0.3867</td>
#       <td id="T_6f642_row1_col1" class="data row1 col1" >0.9062</td>
#       <td id="T_6f642_row1_col2" class="data row1 col2" >0.5421</td>
#       <td id="T_6f642_row1_col3" class="data row1 col3" >32</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row2" class="row_heading level0 row2" >percussion</th>
#       <td id="T_6f642_row2_col0" class="data row2 col0" >0.3288</td>
#       <td id="T_6f642_row2_col1" class="data row2 col1" >0.8276</td>
#       <td id="T_6f642_row2_col2" class="data row2 col2" >0.4706</td>
#       <td id="T_6f642_row2_col3" class="data row2 col3" >29</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row3" class="row_heading level0 row3" >woodwind</th>
#       <td id="T_6f642_row3_col0" class="data row3 col0" >0.0000</td>
#       <td id="T_6f642_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_6f642_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_6f642_row3_col3" class="data row3 col3" >30</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row4" class="row_heading level0 row4" >sheng</th>
#       <td id="T_6f642_row4_col0" class="data row4 col0" >0.3594</td>
#       <td id="T_6f642_row4_col1" class="data row4 col1" >0.7667</td>
#       <td id="T_6f642_row4_col2" class="data row4 col2" >0.4894</td>
#       <td id="T_6f642_row4_col3" class="data row4 col3" >30</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row5" class="row_heading level0 row5" >dizi</th>
#       <td id="T_6f642_row5_col0" class="data row5 col0" >0.1429</td>
#       <td id="T_6f642_row5_col1" class="data row5 col1" >0.1667</td>
#       <td id="T_6f642_row5_col2" class="data row5 col2" >0.1538</td>
#       <td id="T_6f642_row5_col3" class="data row5 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row6" class="row_heading level0 row6" >timpani</th>
#       <td id="T_6f642_row6_col0" class="data row6 col0" >0.0000</td>
#       <td id="T_6f642_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_6f642_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_6f642_row6_col3" class="data row6 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row7" class="row_heading level0 row7" >erhu</th>
#       <td id="T_6f642_row7_col0" class="data row7 col0" >0.2692</td>
#       <td id="T_6f642_row7_col1" class="data row7 col1" >0.3043</td>
#       <td id="T_6f642_row7_col2" class="data row7 col2" >0.2857</td>
#       <td id="T_6f642_row7_col3" class="data row7 col3" >23</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row8" class="row_heading level0 row8" >pipa</th>
#       <td id="T_6f642_row8_col0" class="data row8 col0" >0.3333</td>
#       <td id="T_6f642_row8_col1" class="data row8 col1" >0.0345</td>
#       <td id="T_6f642_row8_col2" class="data row8 col2" >0.0625</td>
#       <td id="T_6f642_row8_col3" class="data row8 col3" >29</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row9" class="row_heading level0 row9" >suona</th>
#       <td id="T_6f642_row9_col0" class="data row9 col0" >0.0000</td>
#       <td id="T_6f642_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_6f642_row9_col2" class="data row9 col2" >0.0000</td>
#       <td id="T_6f642_row9_col3" class="data row9 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row10" class="row_heading level0 row10" >guzheng</th>
#       <td id="T_6f642_row10_col0" class="data row10 col0" >0.0253</td>
#       <td id="T_6f642_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T_6f642_row10_col2" class="data row10 col2" >0.0494</td>
#       <td id="T_6f642_row10_col3" class="data row10 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row11" class="row_heading level0 row11" >piano</th>
#       <td id="T_6f642_row11_col0" class="data row11 col0" >0.0000</td>
#       <td id="T_6f642_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_6f642_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_6f642_row11_col3" class="data row11 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row12" class="row_heading level0 row12" >guqin</th>
#       <td id="T_6f642_row12_col0" class="data row12 col0" >0.0000</td>
#       <td id="T_6f642_row12_col1" class="data row12 col1" >0.0000</td>
#       <td id="T_6f642_row12_col2" class="data row12 col2" >0.0000</td>
#       <td id="T_6f642_row12_col3" class="data row12 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row13" class="row_heading level0 row13" >xiao</th>
#       <td id="T_6f642_row13_col0" class="data row13 col0" >0.2000</td>
#       <td id="T_6f642_row13_col1" class="data row13 col1" >0.2500</td>
#       <td id="T_6f642_row13_col2" class="data row13 col2" >0.2222</td>
#       <td id="T_6f642_row13_col3" class="data row13 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row14" class="row_heading level0 row14" >yangqin</th>
#       <td id="T_6f642_row14_col0" class="data row14 col0" >0.0000</td>
#       <td id="T_6f642_row14_col1" class="data row14 col1" >0.0000</td>
#       <td id="T_6f642_row14_col2" class="data row14 col2" >0.0000</td>
#       <td id="T_6f642_row14_col3" class="data row14 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row15" class="row_heading level0 row15" >micro avg</th>
#       <td id="T_6f642_row15_col0" class="data row15 col0" >0.2528</td>
#       <td id="T_6f642_row15_col1" class="data row15 col1" >0.3169</td>
#       <td id="T_6f642_row15_col2" class="data row15 col2" >0.2812</td>
#       <td id="T_6f642_row15_col3" class="data row15 col3" >284</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row16" class="row_heading level0 row16" >macro avg</th>
#       <td id="T_6f642_row16_col0" class="data row16 col0" >0.1364</td>
#       <td id="T_6f642_row16_col1" class="data row16 col1" >0.2837</td>
#       <td id="T_6f642_row16_col2" class="data row16 col2" >0.1517</td>
#       <td id="T_6f642_row16_col3" class="data row16 col3" >284</td>
#     </tr>
#     <tr>
#       <th id="T_6f642_level0_row17" class="row_heading level0 row17" >weighted avg</th>
#       <td id=

# %%
# ckpt = torch.load(MODEL_WEIGHTS, map_location=DEVICE)
# audio_cfg = ckpt["audio_config"]
# valid_labels = [c.strip().lower() for c in ckpt["classes"]]
# label_to_idx = {name: i for i, name in enumerate(valid_labels)}
# print(audio_cfg)

# model = CNN(in_ch=2, num_classes=len(valid_labels)).to(DEVICE)
# model.load_state_dict(ckpt['model_state'])

# df = pd.read_csv(TEST_MANIFEST_CSV)

# def _resolve_path(p):
#     p = Path(p)
#     return p if p.is_absolute() else (ROOT / p).resolve()

# df["wav_path"] = df["wav_path"].apply(lambda p: str(_resolve_path(p)))
# df["txt_path"] = df["txt_path"].apply(lambda p: str(_resolve_path(p)))
# all_preds, all_gt, sample_ids = [], [], []

# print(f"Evaluating {len(df)} samples against {len(valid_labels)} classes...")

# for _, row in tqdm(df.iterrows(), total=len(df)):
#     gt_vec = parse_ground_truth(row['txt_path'], label_to_idx)
#     mel = load_and_preprocess(row['wav_path'], audio_cfg)
#     probs = get_prediction(model, mel, DEVICE)

#     all_preds.append(probs)
#     all_gt.append(gt_vec)
#     sample_ids.append(Path(row['wav_path']).stem)


# preds_arr = np.array(all_preds)
# gts_arr = np.array(all_gt)
