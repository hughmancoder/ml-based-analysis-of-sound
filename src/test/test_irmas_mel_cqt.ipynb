# %% [markdown]
# # Test IRMAS (Mel+CQT)

# %%
import sys
import torch
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm import tqdm

ROOT = Path.cwd()
while ROOT != ROOT.parent and not (ROOT / "src").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.models.CRNN import CRNN
from src.test.utils import  display_formatted_results, find_best_threshold
from src.test.utils_mel_cqt import run_inference

MODEL_WEIGHTS     = ROOT / "src/models/saved_weights/IRMAS_mel_cqt_v1/best_val.pt"
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Run on IRMAS Testing Dataset (Mel+CQT)

# %%
test_manifest_csv = ROOT / "data/test/IRMAS/IRMAS-TestingData-Part1.csv"

preds_arr, gts_arr, sample_ids, audio_cfg, valid_labels, label_to_idx = run_inference(
    model_cls=CRNN,
    model_kwargs={"in_ch": 4},
    model_weights_path=MODEL_WEIGHTS,
    device=DEVICE,
    test_manifest_csv=test_manifest_csv,
    root=ROOT,
)
# Out:
# Running inference on 807 samples against 11 classes...
# 100%|██████████| 807/807 [00:18<00:00, 43.51it/s]

# %% [markdown]
# ## Tune classification threshold probability
#
# Optimising macro F1 means:
# - You care equally about rare and common instruments
#
# Optimising micro F1 means:
# - You care about overall instrument detection performance
# - Every correctly detected instrument occurrence matters equally
# - Common instruments dominate

# %%
from src.test.utils import find_best_threshold
best_t = find_best_threshold(preds_arr, gts_arr, valid_labels)
print(f"Best threshold found: {best_t:.2f}")
# print(valid_labels)
# Out:
# Threshold  | Micro F1   | Macro F1   | Subset Acc
# --------------------------------------------------
# 0.05       | 0.5020     | 0.3951     | 22.18%
# 0.10       | 0.4939     | 0.3867     | 22.06%
# 0.15       | 0.4911     | 0.3732     | 22.06%
# 0.20       | 0.4861     | 0.3694     | 21.56%
# 0.25       | 0.4835     | 0.3679     | 21.44%
# 0.30       | 0.4832     | 0.3686     | 21.31%
# 0.35       | 0.4808     | 0.3659     | 21.19%
# 0.40       | 0.4796     | 0.3656     | 21.07%
# 0.45       | 0.4809     | 0.3669     | 21.07%
# 0.50       | 0.4790     | 0.3659     | 20.94%
# 0.55       | 0.4780     | 0.3661     | 20.94%
# 0.60       | 0.4741     | 0.3641     | 20.94%
# 0.65       | 0.4740     | 0.3645     | 20.94%
# 0.70       | 0.4715     | 0.3627     | 20.82%
# 0.75       | 0.4703     | 0.3620     | 20.82%
# 0.80       | 0.4700     | 0.3621     | 20.82%
# 0.85       | 0.4663     | 0.3553     | 20.69%
# 0.90       | 0.4642     | 0.3540     | 20.69%
# 0.95       | 0.4558     | 0.3428     | 20.20%
#
# Best Threshold (Micro F1): 0.05 (Score: 0.5020)
# Best Threshold (Macro F1): 0.05 (Score: 0.3951)
# Best threshold found: 0.05

# %%
import numpy as np
from sklearn.metrics import classification_report, accuracy_score, hamming_loss


def evaluate_multilabel_performance(
    all_preds,
    all_gt,
    class_list,
    sample_ids=None,
    threshold=0.5,
    debug=False,
    zero_division=0,
):
    classes = [c.strip().lower() for c in class_list]
    probs = np.asarray(all_preds)
    gts = np.asarray(all_gt).astype(int)

    if probs.shape != gts.shape:
        raise ValueError(f"Shape mismatch: preds {probs.shape} vs gts {gts.shape}")

    preds = (probs >= threshold).astype(int)

    num_samples, num_classes = preds.shape

    # ---- Key counts ----
    total_pos_gt = int(gts.sum())
    total_pos_pred = int(preds.sum())
    total_entries = int(num_samples * num_classes)

    # Confusion totals across ALL labels (micro)
    tp = int(((preds == 1) & (gts == 1)).sum())
    fp = int(((preds == 1) & (gts == 0)).sum())
    fn = int(((preds == 0) & (gts == 1)).sum())
    tn = int(((preds == 0) & (gts == 0)).sum())

    # ---- None prediction rate ----
    none_pred_mask = preds.sum(axis=1) == 0
    num_none = int(none_pred_mask.sum())

    # ---- Metrics ----
    subset_acc = accuracy_score(gts, preds)                      # exact match
    hamming_acc = 1.0 - hamming_loss(gts, preds)                 # label-wise accuracy

    report = classification_report(
        gts,
        preds,
        target_names=classes,
        output_dict=True,
        zero_division=zero_division,
    )

    # ---- Print summary ----
    print(f"Classification threshold probability: {threshold}")
    print(f"Samples: {num_samples} | Classes: {num_classes} | Decisions: {total_entries}")
    print(f"GT positives: {total_pos_gt} ({total_pos_gt/total_entries:.2%} of all decisions)")
    print(f"Pred positives: {total_pos_pred} ({total_pos_pred/total_entries:.2%} of all decisions)")
    print(f"Predicted 'None' (all-zero): {num_none} ({num_none/num_samples:.2%})")
    print("")
    print(f"Hamming accuracy (label-wise): {hamming_acc:.2%}")
    print(f"Subset accuracy (exact match): {subset_acc:.2%}")
    print(f"Micro F1:  {report['micro avg']['f1-score']:.4f}")
    print(f"Macro F1:  {report['macro avg']['f1-score']:.4f}")
    # print(f"Micro Prec:{report['micro avg']['precision']:.4f} | Micro Rec:{report['micro avg']['recall']:.4f}")
    print("")

    print(f"TP={tp} FP={fp} FN={fn} TN={tn}")
    if total_pos_pred < max(5, 0.02 * total_pos_gt):
        print("WARNING: Very few positive predictions relative to GT positives.")
        print("         Your threshold is likely too high, or logits are miscalibrated.\n")

    # ---- Per-class table ----
    pos_per_class = gts.sum(axis=0)
    print(f"{'Instrument':<15} | {'Prec':>6} | {'Recall':>6} | {'F1':>6} | {'Support':>7} | {'Pred':>5}")
    print("-" * 70)

    for i, name in enumerate(classes):
        support = int(pos_per_class[i])
        pred_count = int(preds[:, i].sum())

        if support == 0:
            print(f"{name:<15} | {'  n/a':>6} | {'  n/a':>6} | {'  n/a':>6} | {support:>7} | {pred_count:>5}")
            continue

        prec = report[name]["precision"]
        rec = report[name]["recall"]
        f1 = report[name]["f1-score"]
        print(f"{name:<15} | {prec:6.2f} | {rec:6.2f} | {f1:6.2f} | {support:>7} | {pred_count:>5}")

    # ---- Debug examples where GT had positives ----
    if debug and sample_ids is not None:
        print("\n--- DEBUG: Examples where GT has at least one label ---")
        gt_nonzero = np.where(gts.sum(axis=1) > 0)[0]
        for idx in gt_nonzero[:]:
            pred_names = [classes[j] for j, v in enumerate(preds[idx]) if v]
            gt_names = [classes[j] for j, v in enumerate(gts[idx]) if v]
            print(f"ID: {sample_ids[idx]}")
            print(f"  Predicted: {pred_names if pred_names else '(none)'}")
            print(f"  Actual:    {gt_names if gt_names else '(none)'}")
            print("-" * 30)

    return report

# Default is 0.5; could optionally adjust based on precision-recall tradeoff desired
# threshold_probability = 0.5

threshold_probability = best_t
# threshold_probability = 0.9

results = evaluate_multilabel_performance(
    all_preds=preds_arr, 
    all_gt=gts_arr, 
    class_list=valid_labels, 
    sample_ids=sample_ids,
    threshold=threshold_probability,
    debug=True
)
# Out:
# Classification threshold probability: 0.05
# Samples: 807 | Classes: 11 | Decisions: 8877
# GT positives: 1432 (16.13% of all decisions)
# Pred positives: 787 (8.87% of all decisions)
# Predicted 'None' (all-zero): 52 (6.44%)
#
# Hamming accuracy (label-wise): 87.55%
# Subset accuracy (exact match): 22.18%
# Micro F1:  0.5020
# Macro F1:  0.3951
#
# TP=557 FP=230 FN=875 TN=7215
# Instrument      |   Prec | Recall |     F1 | Support |  Pred
# ----------------------------------------------------------------------
# cel             |   0.29 |   0.19 |   0.23 |      26 |    17
# cla             |   0.04 |   0.12 |   0.06 |       8 |    24
# flu             |   0.26 |   0.36 |   0.30 |      28 |    39
# gac             |   0.78 |   0.55 |   0.65 |     145 |   103
# gel             |   0.84 |   0.24 |   0.37 |     241 |    69
# org             |   0.52 |   0.37 |   0.44 |      91 |    65
# pia             |   0.94 |   0.22 |   0.35 |     367 |    85
# sax             |   0.72 |   0.55 |   0.63 |     167 |   127
# tru             |   0.47 |   0.30 |   0.37 |      79 |    51
# vio             |   0.28 |   0.10 |   0.14 |      51 |    18
# voi             |   0.89 |   0.73 |   0.80 |     229 |   189
#
# --- DEBUG: Examples where GT has at least one label ---
# ID: (02) dont kill the whale-1
#   Predicted: ['tru']
#   Actual:    ['gel']
# ------------------------------
# ID: (02) dont kill the whale-11
#   Predicted: ['tru']
#   Actual:    ['gel']
# ------------------------------
# ID: (02) dont kill the whale-12
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: (02) dont kill the whale-13
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: (02) dont kill the whale-14
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: (02) dont kill the whale-15
#   Predicted: ['gel']
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: (02) dont kill the whale-2
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: (02) dont kill the whale-3
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: (02) dont kill the whale-4
#   Predicted: ['voi']
#   Actual:    ['gel']
# ------------------------------
# ID: (02) dont kill the whale-6
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: (02) dont kill the whale-8
#   Predicted: ['vio']
#   Actual:    ['gel']
# ------------------------------
# ID: (02) dont kill the whale-9
#   Predicted: ['org']
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: 00 - gold fronts-1
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 00 - gold fronts-10
#   Predicted: ['cel']
#   Actual:    ['gel']
# ------------------------------
# ID: 00 - gold fronts-12
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 00 - gold fronts-13
#   Predicted: ['gac']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 00 - gold fronts-2
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 00 - gold fronts-3
#   Predicted: ['gel']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 00 - gold fronts-4
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 00 - gold fronts-5
#   Predicted: ['cel']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 00 - gold fronts-7
#   Predicted: ['vio']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 00 - gold fronts-8
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 00 - yazoo - dont go-3
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 00 - yazoo - dont go-4
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 00 - yazoo - dont go-5
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 00 - yazoo - dont go-8
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 00 - yazoo - dont go-9
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - 999-1
#   Predicted: ['gel']
#   Actual:    ['gel']
# ------------------------------
# ID: 01 - 999-10
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - 999-11
#   Predicted: ['voi']
#   Actual:    ['gel', 'org', 'voi']
# ------------------------------
# ID: 01 - 999-12
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - 999-13
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - 999-15
#   Predicted: ['voi']
#   Actual:    ['gel', 'org', 'voi']
# ------------------------------
# ID: 01 - 999-17
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - 999-18
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - 999-2
#   Predicted: ['gel', 'voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - 999-20
#   Predicted: ['gel', 'voi']
#   Actual:    ['gel', 'org', 'voi']
# ------------------------------
# ID: 01 - 999-4
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - 999-5
#   Predicted: ['voi']
#   Actual:    ['gel', 'org', 'voi']
# ------------------------------
# ID: 01 - 999-6
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - 999-8
#   Predicted: ['voi']
#   Actual:    ['gel', 'org', 'voi']
# ------------------------------
# ID: 01 - Airdrop-10
#   Predicted: ['gel']
#   Actual:    ['gel']
# ------------------------------
# ID: 01 - Airdrop-2
#   Predicted: ['cel']
#   Actual:    ['gel']
# ------------------------------
# ID: 01 - Airdrop-3
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - Airdrop-4
#   Predicted: ['cel']
#   Actual:    ['cel', 'gel']
# ------------------------------
# ID: 01 - Airdrop-6
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - Airdrop-8
#   Predicted: ['cel']
#   Actual:    ['gel']
# ------------------------------
# ID: 01 - Airdrop-9
#   Predicted: ['gel']
#   Actual:    ['gel']
# ------------------------------
# ID: 01 - Canto das tre虃s rac抬as-10
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - Canto das tre虃s rac抬as-11
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - Canto das tre虃s rac抬as-12
#   Predicted: ['pia']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - Canto das tre虃s rac抬as-13
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - Canto das tre虃s rac抬as-14
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - Canto das tre虃s rac抬as-2
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - Canto das tre虃s rac抬as-3
#   Predicted: ['sax']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - Canto das tre虃s rac抬as-4
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - Canto das tre虃s rac抬as-5
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - Canto das tre虃s rac抬as-6
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - Canto das tre虃s rac抬as-8
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - Canto das tre虃s rac抬as-9
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-1
#   Predicted: ['flu']
#   Actual:    ['sax', 'tru']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-11
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-12
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-14
#   Predicted: ['pia']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-15
#   Predicted: ['cla']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-17
#   Predicted: (none)
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-18
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-2
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax', 'tru']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-20
#   Predicted: (none)
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-21
#   Predicted: ['flu']
#   Actual:    ['pia', 'sax', 'tru']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-22
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax', 'tru']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-24
#   Predicted: ['flu']
#   Actual:    ['sax', 'tru']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-3
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax', 'tru']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-5
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-6
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-8
#   Predicted: ['flu']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 - Chet Baker - Prayer For The Newborn-9
#   Predicted: ['sax']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 - Da Duh Dah-1
#   Predicted: ['flu']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Da Duh Dah-10
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Da Duh Dah-11
#   Predicted: ['flu']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Da Duh Dah-13
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax', 'tru']
# ------------------------------
# ID: 01 - Da Duh Dah-15
#   Predicted: ['sax']
#   Actual:    ['sax', 'tru']
# ------------------------------
# ID: 01 - Da Duh Dah-18
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax', 'tru']
# ------------------------------
# ID: 01 - Da Duh Dah-2
#   Predicted: ['cla', 'sax']
#   Actual:    ['pia', 'sax', 'tru']
# ------------------------------
# ID: 01 - Da Duh Dah-4
#   Predicted: ['flu']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 - Da Duh Dah-5
#   Predicted: (none)
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 - Da Duh Dah-7
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Da Duh Dah-8
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Hilary Hahnn_BWV 1042 - I. AllegroA-15
#   Predicted: ['vio']
#   Actual:    ['vio']
# ------------------------------
# ID: 01 - Honky Cat-1
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Honky Cat-10
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-11
#   Predicted: (none)
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-12
#   Predicted: ['sax']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Honky Cat-14
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-15
#   Predicted: ['vio']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-16
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-18
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-19
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-2
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-20
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-21
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-22
#   Predicted: ['org']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-23
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-24
#   Predicted: ['sax', 'tru']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Honky Cat-25
#   Predicted: ['gel']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Honky Cat-26
#   Predicted: ['voi']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Honky Cat-27
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Honky Cat-28
#   Predicted: ['sax']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Honky Cat-29
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Honky Cat-30
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-31
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-32
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Honky Cat-4
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-5
#   Predicted: ['gac']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-6
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-7
#   Predicted: (none)
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Honky Cat-8
#   Predicted: ['gac', 'voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Inolvidable-1
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Inolvidable-10
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Inolvidable-11
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Inolvidable-12
#   Predicted: ['flu']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - Inolvidable-13
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Inolvidable-2
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Inolvidable-3
#   Predicted: ['sax', 'voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Inolvidable-4
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - Inolvidable-5
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Inolvidable-6
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Inolvidable-7
#   Predicted: (none)
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Inolvidable-9
#   Predicted: ['voi']
#   Actual:    ['pia', 'voi']
# ------------------------------
# ID: 01 - La leyenda del tiempo-11
#   Predicted: ['org']
#   Actual:    ['gac', 'org']
# ------------------------------
# ID: 01 - La leyenda del tiempo-13
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - La leyenda del tiempo-15
#   Predicted: ['org']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - La leyenda del tiempo-2
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - La leyenda del tiempo-3
#   Predicted: ['org']
#   Actual:    ['gac', 'org']
# ------------------------------
# ID: 01 - La leyenda del tiempo-4
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - La leyenda del tiempo-5
#   Predicted: ['sax']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - La leyenda del tiempo-6
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - La leyenda del tiempo-7
#   Predicted: ['org']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - La leyenda del tiempo-9
#   Predicted: (none)
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 - Led Zeppelin - Custard Pie-1
#   Predicted: (none)
#   Actual:    ['gel']
# ------------------------------
# ID: 01 - Led Zeppelin - Custard Pie-10
#   Predicted: ['gel']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - Led Zeppelin - Custard Pie-12
#   Predicted: ['gel']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - Led Zeppelin - Custard Pie-13
#   Predicted: ['gel', 'voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - Led Zeppelin - Custard Pie-14
#   Predicted: ['gel']
#   Actual:    ['gel']
# ------------------------------
# ID: 01 - Led Zeppelin - Custard Pie-15
#   Predicted: ['gel']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - Led Zeppelin - Custard Pie-16
#   Predicted: ['gel']
#   Actual:    ['gel']
# ------------------------------
# ID: 01 - Led Zeppelin - Custard Pie-2
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - Led Zeppelin - Custard Pie-3
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - Led Zeppelin - Custard Pie-4
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - Led Zeppelin - Custard Pie-5
#   Predicted: ['gel', 'vio']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - Led Zeppelin - Custard Pie-7
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 01 - Led Zeppelin - Custard Pie-8
#   Predicted: ['voi']
#   Actual:    ['gel']
# ------------------------------
# ID: 01 - Orchids in the Moonlight-1
#   Predicted: ['gac', 'org']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Orchids in the Moonlight-10
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Orchids in the Moonlight-11
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Orchids in the Moonlight-2
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Orchids in the Moonlight-3
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Orchids in the Moonlight-5
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Orchids in the Moonlight-6
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Orchids in the Moonlight-7
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Orchids in the Moonlight-8
#   Predicted: ['org']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Orchids in the Moonlight-9
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Paganini - Eliot Fisk, Guitar - No. 1 in E-major-1
#   Predicted: ['cel', 'gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Paganini - Eliot Fisk, Guitar - No. 1 in E-major-2
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Paganini - Eliot Fisk, Guitar - No. 1 in E-major-3
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Paganini - Eliot Fisk, Guitar - No. 1 in E-major-4
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Paganini - Eliot Fisk, Guitar - No. 1 in E-major-5
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Paganini - Eliot Fisk, Guitar - No. 1 in E-major-6
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 - Roadgame-1
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - Roadgame-10
#   Predicted: ['flu', 'pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Roadgame-12
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Roadgame-13
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Roadgame-14
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Roadgame-15
#   Predicted: ['tru']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Roadgame-16
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Roadgame-17
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Roadgame-18
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Roadgame-19
#   Predicted: (none)
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Roadgame-21
#   Predicted: ['org']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Roadgame-22
#   Predicted: (none)
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Roadgame-23
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Roadgame-24
#   Predicted: (none)
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Roadgame-26
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Roadgame-27
#   Predicted: ['pia']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Roadgame-28
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Roadgame-3
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Roadgame-30
#   Predicted: ['flu']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Roadgame-32
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Roadgame-33
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Roadgame-4
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Roadgame-6
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Roadgame-7
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Roadgame-8
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - Roadgame-9
#   Predicted: ['flu']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - roads-12
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - roads-13
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - roads-15
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - roads-18
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - roads-19
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - roads-20
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - roads-21
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - roads-22
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - roads-23
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - roads-4
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - roads-5
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - roads-7
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - roads-8
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 - So What-1
#   Predicted: (none)
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - So What-10
#   Predicted: ['flu']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 - So What-11
#   Predicted: ['tru']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 - So What-13
#   Predicted: (none)
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - So What-14
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - So What-15
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - So What-16
#   Predicted: ['tru']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - So What-17
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - So What-18
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - So What-19
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - So What-20
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - So What-21
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - So What-22
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - So What-24
#   Predicted: (none)
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - So What-25
#   Predicted: ['flu']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - So What-27
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - So What-29
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - So What-31
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - So What-4
#   Predicted: ['org', 'pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - So What-5
#   Predicted: (none)
#   Actual:    ['pia']
# ------------------------------
# ID: 01 - So What-7
#   Predicted: ['tru']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 - So What-8
#   Predicted: ['pia']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 - So What-9
#   Predicted: ['tru']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 - Wee Baby Blues-1
#   Predicted: ['voi']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 - Wee Baby Blues-11
#   Predicted: ['voi']
#   Actual:    ['gel', 'pia', 'voi']
# ------------------------------
# ID: 01 - Wee Baby Blues-2
#   Predicted: (none)
#   Actual:    ['gel', 'pia', 'voi']
# ------------------------------
# ID: 01 - Wee Baby Blues-3
#   Predicted: ['pia']
#   Actual:    ['gel', 'pia', 'voi']
# ------------------------------
# ID: 01 - Wee Baby Blues-4
#   Predicted: ['voi']
#   Actual:    ['gel', 'pia', 'voi']
# ------------------------------
# ID: 01 - Wee Baby Blues-6
#   Predicted: (none)
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: 01 - Wee Baby Blues-7
#   Predicted: ['cel']
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: 01 - Wee Baby Blues-9
#   Predicted: ['gel']
#   Actual:    ['gel', 'pia', 'sax']
# ------------------------------
# ID: 01 Blue Train-1
#   Predicted: ['sax']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Blue Train-10
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Blue Train-12
#   Predicted: ['sax', 'tru']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Blue Train-14
#   Predicted: ['sax']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 Blue Train-15
#   Predicted: ['sax', 'tru']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 Blue Train-16
#   Predicted: ['sax']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 Blue Train-17
#   Predicted: ['tru']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 Blue Train-18
#   Predicted: ['tru']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 Blue Train-20
#   Predicted: ['flu']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Blue Train-21
#   Predicted: (none)
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Blue Train-22
#   Predicted: ['sax']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Blue Train-23
#   Predicted: ['org']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Blue Train-25
#   Predicted: ['tru']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Blue Train-26
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Blue Train-27
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Blue Train-28
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Blue Train-29
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Blue Train-3
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Blue Train-30
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Blue Train-31
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Blue Train-36
#   Predicted: ['sax']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Blue Train-37
#   Predicted: ['sax']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Blue Train-4
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Blue Train-5
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Blue Train-6
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Blue Train-7
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Blue Train-9
#   Predicted: ['cla']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Booker T. Jones - Pound It Out-1
#   Predicted: ['gel']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Booker T. Jones - Pound It Out-10
#   Predicted: ['gel']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Booker T. Jones - Pound It Out-11
#   Predicted: ['gel']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Booker T. Jones - Pound It Out-12
#   Predicted: ['voi']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Booker T. Jones - Pound It Out-13
#   Predicted: ['sax']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Booker T. Jones - Pound It Out-3
#   Predicted: ['voi']
#   Actual:    ['gel']
# ------------------------------
# ID: 01 Booker T. Jones - Pound It Out-4
#   Predicted: ['gel']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Booker T. Jones - Pound It Out-6
#   Predicted: ['gel']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Booker T. Jones - Pound It Out-8
#   Predicted: ['gel']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Booker T. Jones - Pound It Out-9
#   Predicted: ['pia']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-1
#   Predicted: ['sax']
#   Actual:    ['gac', 'tru']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-10
#   Predicted: (none)
#   Actual:    ['gel', 'sax', 'tru']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-12
#   Predicted: (none)
#   Actual:    ['gac', 'gel']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-13
#   Predicted: ['gel', 'org']
#   Actual:    ['gac', 'gel', 'sax']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-14
#   Predicted: ['pia']
#   Actual:    ['gac', 'gel']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-16
#   Predicted: ['tru']
#   Actual:    ['gel', 'sax']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-17
#   Predicted: (none)
#   Actual:    ['gel', 'sax']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-18
#   Predicted: ['gel']
#   Actual:    ['gel', 'sax']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-2
#   Predicted: ['cla']
#   Actual:    ['gac', 'tru']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-20
#   Predicted: ['org']
#   Actual:    ['gac', 'gel']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-21
#   Predicted: ['org']
#   Actual:    ['gac', 'gel']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-22
#   Predicted: ['org']
#   Actual:    ['gac', 'gel']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-24
#   Predicted: ['cla']
#   Actual:    ['gac', 'gel', 'tru']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-26
#   Predicted: ['tru']
#   Actual:    ['gac', 'gel', 'sax', 'tru']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-27
#   Predicted: ['org']
#   Actual:    ['gac', 'gel', 'sax', 'tru']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-29
#   Predicted: ['gel']
#   Actual:    ['gac', 'gel', 'sax']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-3
#   Predicted: ['cla']
#   Actual:    ['gac', 'tru']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-30
#   Predicted: ['tru']
#   Actual:    ['gac', 'gel', 'sax', 'tru']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-31
#   Predicted: (none)
#   Actual:    ['gac', 'gel', 'sax', 'tru']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-32
#   Predicted: ['tru']
#   Actual:    ['gac', 'gel', 'sax', 'tru']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-33
#   Predicted: (none)
#   Actual:    ['gac', 'gel', 'sax', 'tru']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-34
#   Predicted: ['org']
#   Actual:    ['gac', 'gel', 'sax', 'tru']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-4
#   Predicted: ['tru']
#   Actual:    ['gac', 'tru']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-6
#   Predicted: ['org']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-8
#   Predicted: ['tru']
#   Actual:    ['gel', 'tru']
# ------------------------------
# ID: 01 Chuck Mangione_Feels So Good_Feels So Good-9
#   Predicted: ['tru']
#   Actual:    ['gel', 'sax', 'tru']
# ------------------------------
# ID: 01 Don't Get Around Much Anymore-1
#   Predicted: ['voi']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Don't Get Around Much Anymore-10
#   Predicted: ['voi']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Don't Get Around Much Anymore-12
#   Predicted: ['tru']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Don't Get Around Much Anymore-13
#   Predicted: ['voi']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Don't Get Around Much Anymore-14
#   Predicted: ['voi']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Don't Get Around Much Anymore-16
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax', 'tru']
# ------------------------------
# ID: 01 Don't Get Around Much Anymore-18
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Don't Get Around Much Anymore-2
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Don't Get Around Much Anymore-3
#   Predicted: ['sax', 'tru']
#   Actual:    ['pia', 'sax', 'tru']
# ------------------------------
# ID: 01 Don't Get Around Much Anymore-4
#   Predicted: (none)
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Don't Get Around Much Anymore-5
#   Predicted: ['sax', 'tru']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Don't Get Around Much Anymore-6
#   Predicted: ['tru']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Don't Get Around Much Anymore-7
#   Predicted: ['tru']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 Don't Get Around Much Anymore-8
#   Predicted: ['sax', 'tru']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01 Don't Get Around Much Anymore-9
#   Predicted: (none)
#   Actual:    ['pia']
# ------------------------------
# ID: 01 El Patufet-1
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 El Patufet-3
#   Predicted: ['tru']
#   Actual:    ['flu']
# ------------------------------
# ID: 01 El Patufet-5
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 El Patufet-6
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 El Patufet-7
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 Emily-1
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 Emily-10
#   Predicted: ['voi']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-11
#   Predicted: ['voi']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-13
#   Predicted: ['voi']
#   Actual:    ['cel', 'voi']
# ------------------------------
# ID: 01 Emily-15
#   Predicted: ['cel']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-16
#   Predicted: ['voi']
#   Actual:    ['cel', 'voi']
# ------------------------------
# ID: 01 Emily-18
#   Predicted: ['voi']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-19
#   Predicted: ['voi']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-2
#   Predicted: ['voi']
#   Actual:    ['vio', 'voi']
# ------------------------------
# ID: 01 Emily-20
#   Predicted: ['voi']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-21
#   Predicted: ['voi']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-22
#   Predicted: ['voi']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-23
#   Predicted: ['cla']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-24
#   Predicted: ['voi']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-26
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 Emily-28
#   Predicted: ['voi']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-29
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 Emily-30
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 Emily-32
#   Predicted: ['voi']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-34
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 Emily-35
#   Predicted: ['voi']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-36
#   Predicted: ['vio']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-37
#   Predicted: ['voi']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-38
#   Predicted: ['voi']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-40
#   Predicted: ['vio']
#   Actual:    ['cel', 'vio']
# ------------------------------
# ID: 01 Emily-5
#   Predicted: ['voi']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-6
#   Predicted: ['cel']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-7
#   Predicted: ['cel']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-8
#   Predicted: ['voi']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Emily-9
#   Predicted: ['cel']
#   Actual:    ['cel', 'vio', 'voi']
# ------------------------------
# ID: 01 Good Vibrations-1
#   Predicted: (none)
#   Actual:    ['gel', 'sax']
# ------------------------------
# ID: 01 Good Vibrations-10
#   Predicted: ['sax']
#   Actual:    ['gel', 'sax']
# ------------------------------
# ID: 01 Good Vibrations-12
#   Predicted: ['sax']
#   Actual:    ['org', 'sax']
# ------------------------------
# ID: 01 Good Vibrations-13
#   Predicted: (none)
#   Actual:    ['org', 'sax']
# ------------------------------
# ID: 01 Good Vibrations-14
#   Predicted: ['sax']
#   Actual:    ['org', 'sax']
# ------------------------------
# ID: 01 Good Vibrations-15
#   Predicted: ['cla']
#   Actual:    ['org', 'sax']
# ------------------------------
# ID: 01 Good Vibrations-17
#   Predicted: ['gel']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Good Vibrations-18
#   Predicted: ['gel']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Good Vibrations-20
#   Predicted: ['gac']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01 Good Vibrations-21
#   Predicted: ['gel']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Good Vibrations-22
#   Predicted: ['gel']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Good Vibrations-24
#   Predicted: ['sax']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01 Good Vibrations-25
#   Predicted: ['cla']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01 Good Vibrations-26
#   Predicted: ['voi']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01 Good Vibrations-27
#   Predicted: (none)
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01 Good Vibrations-28
#   Predicted: ['voi']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01 Good Vibrations-29
#   Predicted: ['sax']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01 Good Vibrations-3
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Good Vibrations-4
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Good Vibrations-5
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Good Vibrations-6
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Good Vibrations-7
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Good Vibrations-9
#   Predicted: ['sax']
#   Actual:    ['gel', 'sax']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-1
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-10
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-11
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-12
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-13
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-14
#   Predicted: (none)
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-15
#   Predicted: ['vio']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-16
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-17
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-18
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-19
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-2
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-20
#   Predicted: ['vio']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-21
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-3
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-4
#   Predicted: ['cla']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-5
#   Predicted: ['cla', 'gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-6
#   Predicted: ['gac', 'voi']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-7
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-8
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Julian Bream - Albeniz- Mallorca, Opus 202-9
#   Predicted: ['cla']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Just One Of Those Things-1
#   Predicted: ['tru']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Just One Of Those Things-10
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Just One Of Those Things-11
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Just One Of Those Things-12
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Just One Of Those Things-14
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Just One Of Those Things-15
#   Predicted: ['org']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Just One Of Those Things-16
#   Predicted: ['org']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Just One Of Those Things-17
#   Predicted: (none)
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Just One Of Those Things-18
#   Predicted: ['vio']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Just One Of Those Things-19
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01 Just One Of Those Things-2
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Just One Of Those Things-21
#   Predicted: ['tru']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Just One Of Those Things-22
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Just One Of Those Things-23
#   Predicted: ['tru']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Just One Of Those Things-4
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Just One Of Those Things-5
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Just One Of Those Things-6
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Just One Of Those Things-7
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Just One Of Those Things-8
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Just One Of Those Things-9
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01 Organ Grinder's Swing-1
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Organ Grinder's Swing-2
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Organ Grinder's Swing-3
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Organ Grinder's Swing-4
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Organ Grinder's Swing-5
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Organ Grinder's Swing-7
#   Predicted: ['voi']
#   Actual:    ['voi']
# ------------------------------
# ID: 01 Organ Grinder's Swing-8
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01 Start Making Noise-1
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: 01 Start Making Noise-10
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 Start Making Noise-11
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 Start Making Noise-13
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 Start Making Noise-15
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 Start Making Noise-16
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 Start Making Noise-2
#   Predicted: ['gac']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 Start Making Noise-4
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ------------------------------
# ID: 01 Start Making Noise-6
#   Predicted: ['voi']
#   Actual:    ['gac', 'voi']
# ...
# ID: 01. sensing-10
#   Predicted: ['pia']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. sensing-12
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01. sensing-13
#   Predicted: (none)
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. sensing-14
#   Predicted: ['sax', 'tru']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. sensing-15
#   Predicted: ['pia']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. sensing-2
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01. sensing-3
#   Predicted: ['flu']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. sensing-5
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01. sensing-6
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. sensing-8
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01. sensing-9
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-1
#   Predicted: ['pia']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-10
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-11
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-12
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-13
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-15
#   Predicted: ['sax']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-16
#   Predicted: ['sax']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-17
#   Predicted: ['pia']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-18
#   Predicted: ['vio']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-2
#   Predicted: ['pia']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-20
#   Predicted: ['sax']
#   Actual:    ['pia']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-21
#   Predicted: (none)
#   Actual:    ['pia']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-22
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-23
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-24
#   Predicted: ['sax']
#   Actual:    ['pia']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-25
#   Predicted: ['sax']
#   Actual:    ['pia']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-26
#   Predicted: ['sax']
#   Actual:    ['pia']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-27
#   Predicted: ['sax']
#   Actual:    ['pia']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-3
#   Predicted: (none)
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-4
#   Predicted: (none)
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-6
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-7
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-8
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. The Best Of Wayne Shorter - The Blue Note Years - [Speak No Evil]-9
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 01. The Chosen Hour-2
#   Predicted: ['org']
#   Actual:    ['voi']
# ------------------------------
# ID: 01. Trouble (No. 2)-1
#   Predicted: ['gac']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01. Trouble (No. 2)-10
#   Predicted: ['gac']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01. Trouble (No. 2)-12
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01. Trouble (No. 2)-13
#   Predicted: ['flu']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01. Trouble (No. 2)-14
#   Predicted: ['flu']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01. Trouble (No. 2)-15
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01. Trouble (No. 2)-16
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01. Trouble (No. 2)-17
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01. Trouble (No. 2)-18
#   Predicted: ['org']
#   Actual:    ['gel', 'org']
# ------------------------------
# ID: 01. Trouble (No. 2)-2
#   Predicted: (none)
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01. Trouble (No. 2)-20
#   Predicted: ['sax']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01. Trouble (No. 2)-21
#   Predicted: ['gac']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01. Trouble (No. 2)-22
#   Predicted: ['gac']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01. Trouble (No. 2)-23
#   Predicted: ['gac']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01. Trouble (No. 2)-24
#   Predicted: ['gac']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01. Trouble (No. 2)-3
#   Predicted: ['sax']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01. Trouble (No. 2)-4
#   Predicted: ['gel']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01. Trouble (No. 2)-5
#   Predicted: ['gac']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01. Trouble (No. 2)-6
#   Predicted: ['org']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01. Trouble (No. 2)-7
#   Predicted: ['gac']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01. Trouble (No. 2)-8
#   Predicted: ['gel']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 01. Trouble (No. 2)-9
#   Predicted: ['org']
#   Actual:    ['gel', 'org', 'sax']
# ------------------------------
# ID: 02 - And The Body Will Die-1
#   Predicted: ['gel']
#   Actual:    ['gel']
# ------------------------------
# ID: 02 - And The Body Will Die-10
#   Predicted: ['voi']
#   Actual:    ['gel']
# ------------------------------
# ID: 02 - And The Body Will Die-12
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 02 - And The Body Will Die-13
#   Predicted: ['voi']
#   Actual:    ['gel']
# ------------------------------
# ID: 02 - And The Body Will Die-14
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 02 - And The Body Will Die-15
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 02 - And The Body Will Die-16
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 02 - And The Body Will Die-17
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 02 - And The Body Will Die-2
#   Predicted: ['gel']
#   Actual:    ['gel']
# ------------------------------
# ID: 02 - And The Body Will Die-4
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 02 - And The Body Will Die-6
#   Predicted: ['voi']
#   Actual:    ['gel']
# ------------------------------
# ID: 02 - And The Body Will Die-8
#   Predicted: ['voi']
#   Actual:    ['gel', 'voi']
# ------------------------------
# ID: 02 - Bo-Do-1
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 02 - Bo-Do-10
#   Predicted: ['flu']
#   Actual:    ['flu', 'pia']
# ------------------------------
# ID: 02 - Bo-Do-12
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 02 - Bo-Do-13
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 02 - Bo-Do-14
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 02 - Bo-Do-16
#   Predicted: ['flu']
#   Actual:    ['flu', 'pia']
# ------------------------------
# ID: 02 - Bo-Do-17
#   Predicted: ['flu']
#   Actual:    ['flu', 'pia']
# ------------------------------
# ID: 02 - Bo-Do-18
#   Predicted: ['flu']
#   Actual:    ['flu', 'pia']
# ------------------------------
# ID: 02 - Bo-Do-19
#   Predicted: ['flu']
#   Actual:    ['flu', 'pia']
# ------------------------------
# ID: 02 - Bo-Do-2
#   Predicted: ['cla']
#   Actual:    ['flu']
# ------------------------------
# ID: 02 - Bo-Do-20
#   Predicted: ['cla']
#   Actual:    ['flu', 'pia']
# ------------------------------
# ID: 02 - Bo-Do-4
#   Predicted: ['sax']
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: 02 - Bo-Do-5
#   Predicted: ['gel']
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: 02 - Bo-Do-6
#   Predicted: ['gel']
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: 02 - Bo-Do-8
#   Predicted: ['flu']
#   Actual:    ['flu', 'pia']
# ------------------------------
# ID: 02 - Bo-Do-9
#   Predicted: (none)
#   Actual:    ['flu', 'pia']
# ------------------------------
# ID: 02 - synergistic perceptions-10
#   Predicted: ['org']
#   Actual:    ['voi']
# ------------------------------
# ID: 02 - synergistic perceptions-11
#   Predicted: ['gac']
#   Actual:    ['voi']
# ------------------------------
# ID: 02 - synergistic perceptions-13
#   Predicted: ['gel']
#   Actual:    ['voi']
# ------------------------------
# ID: 02 - synergistic perceptions-14
#   Predicted: ['gac']
#   Actual:    ['voi']
# ------------------------------
# ID: 02 - synergistic perceptions-16
#   Predicted: ['gel']
#   Actual:    ['voi']
# ------------------------------
# ID: 02 - Time Remembered-1
#   Predicted: ['gac']
#   Actual:    ['gel']
# ------------------------------
# ID: 02 - Time Remembered-10
#   Predicted: ['pia']
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: 02 - Time Remembered-12
#   Predicted: ['gac']
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: 02 - Time Remembered-14
#   Predicted: ['cla']
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: 02 - Time Remembered-2
#   Predicted: ['cla']
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: 02 - Time Remembered-3
#   Predicted: ['pia']
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: 02 - Time Remembered-4
#   Predicted: ['flu']
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: 02 - Time Remembered-5
#   Predicted: ['flu']
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: 02 - Time Remembered-6
#   Predicted: ['pia']
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: 02 - Time Remembered-8
#   Predicted: ['pia']
#   Actual:    ['gel', 'pia']
# ------------------------------
# ID: 1 - Hank's Other Bag-1
#   Predicted: ['sax']
#   Actual:    ['sax', 'tru']
# ------------------------------
# ID: 1 - Hank's Other Bag-10
#   Predicted: ['gel', 'pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 1 - Hank's Other Bag-11
#   Predicted: (none)
#   Actual:    ['pia']
# ------------------------------
# ID: 1 - Hank's Other Bag-13
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 1 - Hank's Other Bag-14
#   Predicted: (none)
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 1 - Hank's Other Bag-15
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 1 - Hank's Other Bag-16
#   Predicted: (none)
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 1 - Hank's Other Bag-17
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 1 - Hank's Other Bag-19
#   Predicted: ['tru']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 1 - Hank's Other Bag-20
#   Predicted: (none)
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 1 - Hank's Other Bag-21
#   Predicted: ['tru']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 1 - Hank's Other Bag-22
#   Predicted: ['tru']
#   Actual:    ['pia', 'tru']
# ------------------------------
# ID: 1 - Hank's Other Bag-24
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax']
# ------------------------------
# ID: 1 - Hank's Other Bag-26
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax', 'tru']
# ------------------------------
# ID: 1 - Hank's Other Bag-27
#   Predicted: ['org']
#   Actual:    ['pia', 'sax', 'tru']
# ------------------------------
# ID: 1 - Hank's Other Bag-3
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax', 'tru']
# ------------------------------
# ID: 1 - Hank's Other Bag-4
#   Predicted: ['gel']
#   Actual:    ['pia', 'sax', 'tru']
# ------------------------------
# ID: 1 - Hank's Other Bag-5
#   Predicted: ['cel']
#   Actual:    ['pia', 'sax', 'tru']
# ------------------------------
# ID: 1 - Hank's Other Bag-6
#   Predicted: ['sax']
#   Actual:    ['pia', 'sax', 'tru']
# ------------------------------
# ID: 1 - Hank's Other Bag-7
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 1 - Hank's Other Bag-8
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 1 - Hank's Other Bag-9
#   Predicted: ['pia']
#   Actual:    ['pia']
# ------------------------------
# ID: 1.1_Stranger On The Shore-1
#   Predicted: ['voi']
#   Actual:    ['cla']
# ------------------------------
# ID: 1.1_Stranger On The Shore-11
#   Predicted: ['sax']
#   Actual:    ['cla']
# ------------------------------
# ID: 1.1_Stranger On The Shore-12
#   Predicted: (none)
#   Actual:    ['cla']
# ------------------------------
# ID: 1.1_Stranger On The Shore-2
#   Predicted: ['tru']
#   Actual:    ['cla']
# ------------------------------
# ID: 1.1_Stranger On The Shore-3
#   Predicted: ['tru']
#   Actual:    ['cla']
# ------------------------------
# ID: 1.1_Stranger On The Shore-4
#   Predicted: ['cla', 'sax']
#   Actual:    ['cla']
# ------------------------------
# ID: 1.1_Stranger On The Shore-8
#   Predicted: ['tru']
#   Actual:    ['cla']
# ------------------------------
# ID: 1.1_Stranger On The Shore-9
#   Predicted: ['tru']
#   Actual:    ['cla']
# ------------------------------
# ID: [1] - 03 - Alexandre Lagoya - Canarios (Sanz)-1
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: [1] - 03 - Alexandre Lagoya - Canarios (Sanz)-2
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: [1] - 03 - Alexandre Lagoya - Canarios (Sanz)-3
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: [1] - 03 - Alexandre Lagoya - Canarios (Sanz)-4
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: [1] - 03 - Alexandre Lagoya - Canarios (Sanz)-5
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: [1] - 03 - Alexandre Lagoya - Canarios (Sanz)-6
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: [1] - 03 - Alexandre Lagoya - Canarios (Sanz)-7
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------
# ID: [1] - 03 - Alexandre Lagoya - Canarios (Sanz)-8
#   Predicted: ['gac']
#   Actual:    ['gac']
# ------------------------------

# %% [markdown]
# ### Classification Report

# %%
display_formatted_results(results)
# Out:
# --- Detailed Classification Report ---
# <style type="text/css">
# #T_40ac4_row0_col2 {
#   background-color: #ceecb3;
#   color: #000000;
# }
# #T_40ac4_row1_col2 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_40ac4_row2_col2 {
#   background-color: #a0dab8;
#   color: #000000;
# }
# #T_40ac4_row3_col2 {
#   background-color: #2351a2;
#   color: #f1f1f1;
# }
# #T_40ac4_row4_col2 {
#   background-color: #69c5be;
#   color: #000000;
# }
# #T_40ac4_row5_col2 {
#   background-color: #40b5c4;
#   color: #f1f1f1;
# }
# #T_40ac4_row6_col2 {
#   background-color: #76cabc;
#   color: #000000;
# }
# #T_40ac4_row7_col2 {
#   background-color: #225aa6;
#   color: #f1f1f1;
# }
# #T_40ac4_row8_col2 {
#   background-color: #6dc6be;
#   color: #000000;
# }
# #T_40ac4_row9_col2 {
#   background-color: #eff9b6;
#   color: #000000;
# }
# #T_40ac4_row10_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_40ac4_row11_col2 {
#   background-color: #269bc1;
#   color: #f1f1f1;
# }
# #T_40ac4_row12_col2 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# #T_40ac4_row13_col2 {
#   background-color: #2da2c2;
#   color: #f1f1f1;
# }
# #T_40ac4_row14_col2 {
#   background-color: #2296c1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_40ac4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40ac4_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_40ac4_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_40ac4_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_40ac4_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40ac4_level0_row0" class="row_heading level0 row0" >cel</th>
#       <td id="T_40ac4_row0_col0" class="data row0 col0" >0.2941</td>
#       <td id="T_40ac4_row0_col1" class="data row0 col1" >0.1923</td>
#       <td id="T_40ac4_row0_col2" class="data row0 col2" >0.2326</td>
#       <td id="T_40ac4_row0_col3" class="data row0 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_40ac4_level0_row1" class="row_heading level0 row1" >cla</th>
#       <td id="T_40ac4_row1_col0" class="data row1 col0" >0.0417</td>
#       <td id="T_40ac4_row1_col1" class="data row1 col1" >0.1250</td>
#       <td id="T_40ac4_row1_col2" class="data row1 col2" >0.0625</td>
#       <td id="T_40ac4_row1_col3" class="data row1 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_40ac4_level0_row2" class="row_heading level0 row2" >flu</th>
#       <td id="T_40ac4_row2_col0" class="data row2 col0" >0.2564</td>
#       <td id="T_40ac4_row2_col1" class="data row2 col1" >0.3571</td>
#       <td id="T_40ac4_row2_col2" class="data row2 col2" >0.2985</td>
#       <td id="T_40ac4_row2_col3" class="data row2 col3" >28</td>
#     </tr>
#     <tr>
#       <th id="T_40ac4_level0_row3" class="row_heading level0 row3" >gac</th>
#       <td id="T_40ac4_row3_col0" class="data row3 col0" >0.7767</td>
#       <td id="T_40ac4_row3_col1" class="data row3 col1" >0.5517</td>
#       <td id="T_40ac4_row3_col2" class="data row3 col2" >0.6452</td>
#       <td id="T_40ac4_row3_col3" class="data row3 col3" >145</td>
#     </tr>
#     <tr>
#       <th id="T_40ac4_level0_row4" class="row_heading level0 row4" >gel</th>
#       <td id="T_40ac4_row4_col0" class="data row4 col0" >0.8406</td>
#       <td id="T_40ac4_row4_col1" class="data row4 col1" >0.2407</td>
#       <td id="T_40ac4_row4_col2" class="data row4 col2" >0.3742</td>
#       <td id="T_40ac4_row4_col3" class="data row4 col3" >241</td>
#     </tr>
#     <tr>
#       <th id="T_40ac4_level0_row5" class="row_heading level0 row5" >org</th>
#       <td id="T_40ac4_row5_col0" class="data row5 col0" >0.5231</td>
#       <td id="T_40ac4_row5_col1" class="data row5 col1" >0.3736</td>
#       <td id="T_40ac4_row5_col2" class="data row5 col2" >0.4359</td>
#       <td id="T_40ac4_row5_col3" class="data row5 col3" >91</td>
#     </tr>
#     <tr>
#       <th id="T_40ac4_level0_row6" class="row_heading level0 row6" >pia</th>
#       <td id="T_40ac4_row6_col0" class="data row6 col0" >0.9412</td>
#       <td id="T_40ac4_row6_col1" class="data row6 col1" >0.2180</td>
#       <td id="T_40ac4_row6_col2" class="data row6 col2" >0.3540</td>
#       <td id="T_40ac4_row6_col3" class="data row6 col3" >367</td>
#     </tr>
#     <tr>
#       <th id="T_40ac4_level0_row7" class="row_heading level0 row7" >sax</th>
#       <td id="T_40ac4_row7_col0" class="data row7 col0" >0.7244</td>
#       <td id="T_40ac4_row7_col1" class="data row7 col1" >0.5509</td>
#       <td id="T_40ac4_row7_col2" class="data row7 col2" >0.6259</td>
#       <td id="T_40ac4_row7_col3" class="data row7 col3" >167</td>
#     </tr>
#     <tr>
#       <th id="T_40ac4_level0_row8" class="row_heading level0 row8" >tru</th>
#       <td id="T_40ac4_row8_col0" class="data row8 col0" >0.4706</td>
#       <td id="T_40ac4_row8_col1" class="data row8 col1" >0.3038</td>
#       <td id="T_40ac4_row8_col2" class="data row8 col2" >0.3692</td>
#       <td id="T_40ac4_row8_col3" class="data row8 col3" >79</td>
#     </tr>
#     <tr>
#       <th id="T_40ac4_level0_row9" class="row_heading level0 row9" >vio</th>
#       <td id="T_40ac4_row9_col0" class="data row9 col0" >0.2778</td>
#       <td id="T_40ac4_row9_col1" class="data row9 col1" >0.0980</td>
#       <td id="T_40ac4_row9_col2" class="data row9 col2" >0.1449</td>
#       <td id="T_40ac4_row9_col3" class="data row9 col3" >51</td>
#     </tr>
#     <tr>
#       <th id="T_40ac4_level0_row10" class="row_heading level0 row10" >voi</th>
#       <td id="T_40ac4_row10_col0" class="data row10 col0" >0.8889</td>
#       <td id="T_40ac4_row10_col1" class="data row10 col1" >0.7336</td>
#       <td id="T_40ac4_row10_col2" class="data row10 col2" >0.8038</td>
#       <td id="T_40ac4_row10_col3" class="data row10 col3" >229</td>
#     </tr>
#     <tr>
#       <th id="T_40ac4_level0_row11" class="row_heading level0 row11" >micro avg</th>
#       <td id="T_40ac4_row11_col0" class="data row11 col0" >0.7078</td>
#       <td id="T_40ac4_row11_col1" class="data row11 col1" >0.3890</td>
#       <td id="T_40ac4_row11_col2" class="data row11 col2" >0.5020</td>
#       <td id="T_40ac4_row11_col3" class="data row11 col3" >1432</td>
#     </tr>
#     <tr>
#       <th id="T_40ac4_level0_row12" class="row_heading level0 row12" >macro avg</th>
#       <td id="T_40ac4_row12_col0" class="data row12 col0" >0.5487</td>
#       <td id="T_40ac4_row12_col1" class="data row12 col1" >0.3404</td>
#       <td id="T_40ac4_row12_col2" class="data row12 col2" >0.3951</td>
#       <td id="T_40ac4_row12_col3" class="data row12 col3" >1432</td>
#     </tr>
#     <tr>
#       <th id="T_40ac4_level0_row13" class="row_heading level0 row13" >weighted avg</th>
#       <td id="T_40ac4_row13_col0" class="data row13 col0" >0.7676</td>
#       <td id="T_40ac4_row13_col1" class="data row13 col1" >0.3890</td>
#       <td id="T_40ac4_row13_col2" class="data row13 col2" >0.4842</td>
#       <td id="T_40ac4_row13_col3" class="data row13 col3" >1432</td>
#     </tr>
#     <tr>
#       <th id="T_40ac4_level0_row14" class="row_heading level0 row14" >samples avg</th>
#       <td id="T_40ac4_row14_col0" class="data row14 col0" >0.6698</td>
#       <td id="T_40ac4_row14_col1" class="data row14 col1" >0.4447</td>
#       <td id="T_40ac4_row14_col2" class="data row14 col2" >0.5128</td>
#       <td id="T_40ac4_row14_col3" class="data row14 col3" >1432</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ckpt = torch.load(MODEL_WEIGHTS, map_location=DEVICE)
# audio_cfg = ckpt["audio_config"]
# valid_labels = [c.strip().lower() for c in ckpt["classes"]]
# label_to_idx = {name: i for i, name in enumerate(valid_labels)}
# print(audio_cfg)

# model = CRNN(in_ch=2, num_classes=len(valid_labels)).to(DEVICE)
# model.load_state_dict(ckpt['model_state'])

# df = pd.read_csv(TEST_MANIFEST_CSV)

# def _resolve_path(p):
#     p = Path(p)
#     return p if p.is_absolute() else (ROOT / p).resolve()

# df["wav_path"] = df["wav_path"].apply(lambda p: str(_resolve_path(p)))
# df["txt_path"] = df["txt_path"].apply(lambda p: str(_resolve_path(p)))
# all_preds, all_gt, sample_ids = [], [], []

# print(f"Evaluating {len(df)} samples against {len(valid_labels)} classes...")

# for _, row in tqdm(df.iterrows(), total=len(df)):
#     gt_vec = parse_ground_truth(row['txt_path'], label_to_idx)
#     mel = load_and_preprocess(row['wav_path'], audio_cfg)
#     probs = get_prediction(model, mel, DEVICE)

#     all_preds.append(probs)
#     all_gt.append(gt_vec)
#     sample_ids.append(Path(row['wav_path']).stem)


# preds_arr = np.array(all_preds)
# gts_arr = np.array(all_gt)
